# %%
from google.colab import drive # Import a library named google.colab
drive.mount('/content/drive', force_remount=True) # mount the content to the directory `/content/drive`
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Spark/Pyspark-With-Python
# Out:
# /content/drive/MyDrive/Spark/Pyspark-With-Python

# %%
  # !pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.3 MB 34 kB/s
# ...
#      |████████████████████████████████| 198 kB 47.8 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=971aaa8ae32274d8fd7d3f58efc2b940f7a2a6bb3c528a03cc543e134cbc4710
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# ...

# %% [markdown]
# Outlines :
# - PySpark Dataframe
# - Reading The Dataset
# - Checking the Datatypes of the Column(Schema)
# - Selecting Columns And Indexing
# - Check Describe option similar to Pandas
# - Adding Columns
# - Dropping columns
# - Renaming Columns

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://d0a734b7a42c:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read the dataset
df_pyspark=spark.read.option('header','true').csv('test1.csv') 
# inferSchema=True will give the type of the column index

# %%
### Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df_pyspark=spark.read.csv('test1.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
### Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
type(df_pyspark) # DataFrame is a data structure to perform various kinfs of operations
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', age=31, Experience=10, Salary=30000),
#  Row(Name='Sudhanshu', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %%
df_pyspark.columns
# Out:
# ['Name', 'age', 'Experience', 'Salary']

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.select(['Name','Experience']) # select columns to see types
# Out:
# DataFrame[Name: string, Experience: int]

# %%
df_pyspark.select(['Name','Experience']).show() # select columns
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |    Krish|        10|
# |Sudhanshu|         8|
# |    Sunny|         4|
# |     Paul|         3|
# |   Harsha|         1|
# |  Shubham|         2|
# +---------+----------+

# %%
type(df_pyspark.select(['Name','Experience']))
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes # really simialar to pandas
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string, Name: string, age: string, Experience: string, Salary: string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+------+------------------+-----------------+------------------+
# |summary|  Name|               age|       Experience|            Salary|
# +-------+------+------------------+-----------------+------------------+
# |  count|     6|                 6|                6|                 6|
# |   mean|  null|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev|  null| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|Harsha|                21|                1|             15000|
# |    max| Sunny|                31|               10|             30000|
# +-------+------+------------------+-----------------+------------------+

# %%
### Adding Columns in data frame
df_pyspark=df_pyspark.withColumn('Experience After 2 year',df_pyspark['Experience']+2) 
# you have to assign to it like pandas

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+-----------------------+
# |     Name|age|Experience|Salary|Experience After 2 year|
# +---------+---+----------+------+-----------------------+
# |    Krish| 31|        10| 30000|                     12|
# |Sudhanshu| 30|         8| 25000|                     10|
# |    Sunny| 29|         4| 20000|                      6|
# |     Paul| 24|         3| 20000|                      5|
# |   Harsha| 21|         1| 15000|                      3|
# |  Shubham| 23|         2| 18000|                      4|
# +---------+---+----------+------+-----------------------+

# %%
### Drop the columns
df_pyspark=df_pyspark.drop('Experience After 2 year')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
### Rename the columns
df_pyspark.withColumnRenamed('Name','New Name').show()
# Out:
# +---------+---+----------+
# | New Name|age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+
